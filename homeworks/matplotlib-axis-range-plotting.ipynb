# %% [markdown]
# # IE6600 Computation and Visualization for Analytics
#
# ### Matplotlib Library - Part 2
# #### -- STUDENT VERSION --

# %% [markdown]
# #### Set Axis Range (xlim, ylim)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color = 'blue', label = 'Sine wave')
ax.plot(z, color = 'black', label = 'Cosine wave')

plt.show()

# %% [markdown]
# #### Exercise 1 Setting the X-Limit (xlim) for Axes

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color = 'blue', label = 'Sine wave')
ax.plot(z, color = 'black', label = 'Cosine wave')

# --- Added the code here ---
ax.set_xlim(20, 80)   # zoom in on part of the x-axis
# ---------------------------

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax.set_title('Full view')
ax.plot(y, color = 'blue', label = 'Sine wave')
ax.plot(z, color = 'black', label = 'Cosine wave')

ax2.set_title('Truncated view')
ax2.plot(y, color = 'blue', label = 'Sine wave')
ax2.plot(z, color = 'black', label = 'Cosine wave')

# --- Added the code here ---
ax.set_xlim(20, 80)   
# ---------------------------

plt.show()

# %% [markdown]
# #### Exercise 2 Setting the Y-Limit (ylim)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color = 'blue', label = 'Sine wave')
ax.plot(z, color = 'black', label = 'Cosine wave')

# Option 1
# --- Added the code here ---
ax.set_ylim(-1.5, 1.5)
# ---------------------------

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color = 'blue', label = 'Sine wave')
ax.plot(z, color = 'black', label = 'Cosine wave')

# Option 2

# --- Added the code here ---
ax.set_ylim(-1.5, 1.5)
# ---------------------------

plt.show()

# %% [markdown]
# #### Exercise 3 Setting the tight_layout( ) function

# %%
names = ['A', 'B', 'C']
values = [19, 50, 29]
values_2 = [27, 15, 34]

fig = plt.figure(figsize = (8.0, 6.0))

ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax.set_title('Plot Title')
ax.bar(names, values)
ax2.bar(names, values_2)

plt.xlabel("Label for X")
plt.ylabel("Label for Y")
plt.suptitle('Test Plots')

# --- Added the code here ---
plt.tight_layout() 
# ---------------------------

plt.show()

# %% [markdown]
# #### Exercise 4 Setting the subplots_adjust( ) function

# %%
names = ['A', 'B', 'C']
values = [19, 50, 29]
values_2 = [27, 15, 34]

fig = plt.figure(figsize = (8.0, 6.0))

ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax.set_title('Plot Title')
ax.bar(names, values)
ax2.bar(names, values_2)

plt.xlabel("Label for X")
plt.ylabel("Label for Y")
plt.suptitle('Test Plots')

# --- Added the code here ---
plt.subplots_adjust(top=0.85, wspace=0.3) 
# ---------------------------

plt.show()

# %% [markdown]
# ### Change Tick Frequency

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.subplots(figsize = (12.0, 6.0))

x = np.random.randint(low=0, high=50, size=100)
y = np.random.randint(low=0, high=50, size=100)

plt.plot(x, color = 'blue')
plt.plot(y, color = 'black')

plt.show()

# %% [markdown]
# #### Exercise 5 Setting the figure-level tick frequency

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.subplots(figsize = (12.0, 6.0))

x = np.random.randint(low=0, high=50, size=100)
y = np.random.randint(low=0, high=50, size=100)

plt.plot(x, color = 'blue')
plt.plot(y, color = 'black')

# --- Added the code here ---
ticks = np.arange(0, 50, 5)   # ticks every 5 units
plt.xticks(ticks)
plt.yticks(ticks) 
# ---------------------------

plt.show()

# %% [markdown]
# #### Exercise 6 Setting the Axis-level tick frequency

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize = (12.0, 6.0))

ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

x = np.random.randint(low=0, high=50, size=100)
y = np.random.randint(low=0, high=50, size=100)
z = np.random.randint(low=0, high=50, size=100)

ax.plot(x, color = 'blue')
ax.plot(y, color = 'black')
ax2.plot(z, color = 'green')
ax2.plot(y, color = 'black')

# --- Added the code here ---
ax(np.arange()) 
ax(np.arange())  

ax2(np.arange()) 
ax2(np.arange()) 
# ---------------------------

plt.show()

# %% [markdown]
# #### Exercise 7 Rotating X-Axis Tick Labels

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random

fig, ax = plt.subplots(figsize=(8, 4))

x = pd.date_range(datetime.today(), periods=10).tolist()
y = random.sample(range(0, 10), 10)

ax.plot(x, y)
plt.xlabel('Time')
plt.ylabel('Intensity')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random

fig, ax = plt.subplots(figsize=(8, 4))

x = pd.date_range(datetime.today(), periods=10).tolist()
y = random.sample(range(0, 10), 10)

ax.plot(x, y)
plt.xlabel('Time')
plt.ylabel('Intensity')

# --- Added the code here ---
plt.xticks(rotation=45)
# ---------------------------

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random

fig, ax = plt.subplots(figsize=(8, 4))

x = pd.date_range(datetime.today(), periods=10).tolist()
y = random.sample(range(0, 10), 10)

ax.plot(x, y)

# --- Added the code here ---
plt.yticks(rotation=45)
# ---------------------------
    
plt.xlabel('Time')
plt.ylabel('Intensity')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random

fig, ax = plt.subplots(2, 1, figsize=(8, 6))

x = pd.date_range(datetime.today(), periods=10).tolist()
y1 = random.sample(range(0, 10), 10)
y2 = random.sample(range(0, 10), 10)

ax[0].plot(x, y1)
ax[1].plot(x, y2)

# --- Added the code here ---
ax[0].tick_params(axis="x", rotation=45)
ax[1].tick_params(axis="x", rotation=45)
# ---------------------------

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Exercise 8 Rotating Y-Axis Tick Labels

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random

fig, ax = plt.subplots(figsize=(8, 4))

x = pd.date_range(datetime.today(), periods=10).tolist()
y = random.sample(range(0, 10), 10)

ax.plot(x, y)

# --- Added the code here ---
## --- Added the code here ---
plt.yticks(rotation=45)
# ---------------------------

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random

fig, ax = plt.subplots(figsize=(8, 4))

x = pd.date_range(datetime.today(), periods=10).tolist()
y = random.sample(range(0, 10), 10)

ax.plot(x, y)

# --- Added the code here ---
for label in ax.get_yticklabels():
    label.set_rotation(45)
# ---------------------------

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random

fig, ax = plt.subplots(figsize=(8, 4))

x = pd.date_range(datetime.today(), periods=10).tolist()
y = random.sample(range(0, 10), 10)

ax.plot(x, y)

# --- Added the code here ---
ax.tick_params(axis="y", rotation=45)
# ---------------------------

plt.show()

# %% [markdown]
# #### Exercise 9 Rotating Dates to Fit Automatically

# %%
import pandas as pd
import matplotlib.pyplot as plt

weather_data = pd.read_csv('seattleWeather.csv')
# converting the dtype
weather_data['DATE'] = pd.to_datetime(weather_data.DATE)
# Querying only DATE and PRCP
weather_data = weather_data[['DATE', 'PRCP']]

weather_data
# Out:
#             DATE  PRCP
# 0     1948-01-01  0.47
# 1     1948-01-02  0.59
# 2     1948-01-03  0.42
# 3     1948-01-04  0.31
# 4     1948-01-05  0.17
# ...          ...   ...
# 25546 2017-12-10  0.00
# 25547 2017-12-11  0.00
# 25548 2017-12-12  0.00
# 25549 2017-12-13  0.00
# 25550 2017-12-14  0.00
#
# [25551 rows x 2 columns]

# %%
fig = plt.figure()
plt.plot(weather_data['DATE'], weather_data['PRCP'])

# --- Added the code here ---
fig.autofmt_xdate()
# ---------------------------

plt.show()

# %% [markdown]
# ### Draw Vertical Lines on Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

fig, ax = plt.subplots(figsize=(8, 4))

dates = pd.date_range(datetime.today(), periods=15).tolist()
y_1 = [1, 2, 4, 3, 5, 5, 6, 7, 5, 6, 7, 8, 9, 9, 10]
y_2 = [1, 1, 3, 2, 4, 4, 5, 5, 4, 5, 6, 7, 10, 12, 13]

ax.plot(dates, y_1, label = 'Competitor Company')
ax.plot(dates, y_2, label = 'Our Company')

plt.xticks(rotation=15)

plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# #### Exercise 10 Drawing Vertical Lines with Pyplot.vlines( )

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

fig, ax = plt.subplots(figsize=(8, 4))

dates = pd.date_range(datetime.today(), periods=15).tolist()
y_1 = [1, 2, 4, 3, 5, 5, 6, 7, 5, 6, 7, 8, 9, 9, 10]
y_2 = [1, 1, 3, 2, 4, 4, 5, 5, 4, 5, 6, 7, 10, 12, 13]

ax.plot(dates, y_1, label = 'Competitor Company')
ax.plot(dates, y_2, label = 'Our Company')

plt.xticks(rotation=15)

# --- Added the code here ---
# Specify the day 1 and day 2
d1 = datetime.today() + timedelta(days=3)
d2 = datetime.today() + timedelta(days=12)
## --- Added the code here ---
plt.vlines([d1, d2], ymin=0, ymax=max(y), colors='red', linestyles='--')
# ---------------------------

plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

fig, ax = plt.subplots(figsize=(8, 4))

dates = pd.date_range(datetime.today(), periods=15).tolist()
y_1 = [1, 2, 4, 3, 5, 5, 6, 7, 5, 6, 7, 8, 9, 9, 10]
y_2 = [1, 1, 3, 2, 4, 4, 5, 5, 4, 5, 6, 7, 10, 12, 13]

ax.plot(dates, y_1, label = 'Competitor Company')
ax.plot(dates, y_2, label = 'Our Company')

plt.xticks(rotation=15)

# --- Added the code here ---
# Specify the day 1 and day 2
d1 = datetime.today() + timedelta(days=3)
d2 = datetime.today() + timedelta(days=12)
plt.vlines(d1, ymin=0, ymax=max(y_1), colors='red', linestyles='--')
plt.vlines(d2, ymin=0, ymax=max(y_1), colors='red', linestyles='--')

# ---------------------------

plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

fig, ax = plt.subplots(figsize=(8, 4))

dates = pd.date_range(datetime.today(), periods=15).tolist()
y_1 = [1, 2, 4, 3, 5, 5, 6, 7, 5, 6, 7, 8, 9, 9, 10]
y_2 = [1, 1, 3, 2, 4, 4, 5, 5, 4, 5, 6, 7, 10, 12, 13]

ax.plot(dates, y_1, label = 'Competitor Company')
ax.plot(dates, y_2, label = 'Our Company')

plt.xticks(rotation=15)

# --- Added the code here ---
# Specify the day 1 and day 2
d1 = datetime.today() + timedelta(days=3)
d2 = datetime.today() + timedelta(days=12)
ax.vlines([d1, d2], ymin=0, ymax=max(y_1), colors='red', linestyles='--')
# ---------------------------

plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# #### Exercise 11 Drawing Vertical Lines with Pyplot.axvline( )

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

fig, ax = plt.subplots(figsize=(8, 4))

dates = pd.date_range(datetime.today(), periods=15).tolist()
y_1 = [1, 2, 4, 3, 5, 5, 6, 7, 5, 6, 7, 8, 9, 9, 10]
y_2 = [1, 1, 3, 2, 4, 4, 5, 5, 4, 5, 6, 7, 10, 12, 13]

ax.plot(dates, y_1, label = 'Competitor Company')
ax.plot(dates, y_2, label = 'Our Company')

plt.xticks(rotation=15)

# --- Added the code here ---
# Specify the day 1 and day 2
d1 = datetime.today() + timedelta(days=3)
d2 = datetime.today() + timedelta(days=12)
ax.axvline(d1, color='red', linestyle='--', linewidth=2)
ax.axvline(d2, color='red', linestyle='--', linewidth=2)
# ---------------------------

plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

fig, ax = plt.subplots(figsize=(8, 4))

dates = [datetime.today() + timedelta(days=i) for i in range(15)]
y_1 = [1, 2, 4, 3, 5, 5, 6, 7, 5, 6, 7, 8, 9, 9, 10]
y_2 = [1, 1, 3, 2, 4, 4, 5, 5, 4, 5, 6, 7, 10, 12, 13]

ax.plot(dates, y_1, label='Competitor Company')
ax.plot(dates, y_2, label='Our Company')

plt.xticks(rotation=15)
plt.legend(loc='upper left')

# --- Added the code here ---
d1 = datetime.today() + timedelta(days=3)
d2 = datetime.today() + timedelta(days=12)
ax.axvline(d1, color='green', linestyle='--', linewidth=2)     # Promo 1
ax.axvline(d2, color='crimson', linestyle='--', linewidth=2)   # Promo 2
# ---------------------------

plt.show()

# %% [markdown]
# ### List of Named Colors

# %%
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %% [markdown]
# ### Base Colors:

# %%
plot_colortable(mcolors.BASE_COLORS, sort_colors=False, emptycols=1)

# %% [markdown]
# ### Tableau Palette:

# %%
plot_colortable(mcolors.TABLEAU_COLORS, sort_colors=False, emptycols=2)

# %% [markdown]
# ### CSS Colors:

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %% [markdown]
# #### Exercise 12 Changing Colors of Elements

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

fig, ax = plt.subplots(figsize=(8, 4))

dates = pd.date_range(datetime.today(), periods=15).tolist()
y_1 = [1, 2, 4, 3, 5, 5, 6, 7, 5, 6, 7, 8, 9, 9, 10]
y_2 = [1, 1, 3, 2, 4, 4, 5, 5, 4, 5, 6, 7, 10, 12, 13]

ax.plot(dates, y_1, label = 'Competitor Company', color = 'goldenrod')
ax.plot(dates, y_2, label = 'Our Company', color = 'mediumorchid')

plt.xticks(rotation=15)

# --- Added the code here ---
# Specify the day 1 and day 2
d1 = datetime.today() + timedelta(days=3)
d2 = datetime.today() + timedelta(days=12)
ax.axvline(d1, color='green', linestyle='--', linewidth=2)
ax.axvline(d2, color='crimson', linestyle='--', linewidth=2)
# ---------------------------

plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### **Revised Date: January 13, 2026**
